# %% [markdown]
# # Cleaning Dataset and filtering out only house sales in Toronto

# %%
import pandas as pd

# %%
# House Sales in Ontario and read it into pandas
home_sales_df = pd.read_csv("Resources/properties.csv")
home_sales_df.head()
# Out:
#    Unnamed: 0                       Address           AreaName  Price ($)  \
# 0           0       86 Waterford Dr Toronto           Richview     999888
# 1           1  #80 - 100 BEDDOE DR Hamilton     Chedoke Park B     399900
# 2           2    213 Bowman Street Hamilton  Ainslie Wood East     479000
# 3           3      102 NEIL Avenue Hamilton          Greenford     285900
# 4           6   #1409 - 230 King St Toronto           Downtown     362000
#
#          lat        lng
# 0  43.679882 -79.544266
# 1  43.250000 -79.904396
# 2  43.251690 -79.919357
# 3  43.227161 -79.767403
# 4  43.651478 -79.368118

# %%
# Filtering out unwanted column
home_sales_df = home_sales_df[["AreaName","Price ($)","lat","lng","Address"]]
home_sales_df.head()
# Out:
#             AreaName  Price ($)        lat        lng  \
# 0           Richview     999888  43.679882 -79.544266
# 1     Chedoke Park B     399900  43.250000 -79.904396
# 2  Ainslie Wood East     479000  43.251690 -79.919357
# 3          Greenford     285900  43.227161 -79.767403
# 4           Downtown     362000  43.651478 -79.368118
#
#                         Address
# 0       86 Waterford Dr Toronto
# 1  #80 - 100 BEDDOE DR Hamilton
# 2    213 Bowman Street Hamilton
# 3      102 NEIL Avenue Hamilton
# 4   #1409 - 230 King St Toronto

# %%
# Insert a City column by spliting it from Address column
city=[]
for address in home_sales_df["Address"]:
    city.append(address.rsplit(" ",1)[1])

home_sales_df["City"]=city
home_sales_df.head(20)
# Out:
#              AreaName  Price ($)        lat        lng  \
# 0            Richview     999888  43.679882 -79.544266
# 1      Chedoke Park B     399900  43.250000 -79.904396
# 2   Ainslie Wood East     479000  43.251690 -79.919357
# 3           Greenford     285900  43.227161 -79.767403
# 4            Downtown     362000  43.651478 -79.368118
# 5       Old East York    1488000  43.686375 -79.328918
# 6            Fairbank         25  43.691193 -79.461662
# 7    Central Hamilton     254900  43.258541 -79.867615
# 8             Gourley     364900  43.216557 -79.904991
# 9            Red Hill     304900  43.215706 -79.794189
# 10          Clearview    1289000  43.495579 -79.658272
# 11    Wallace Emerson        113  43.664101 -79.439751
# 12      Old East York     599900  43.697842 -79.317368
# 13           Parkdale         97  43.635578 -79.441345
# 14           Parkdale         49  43.635578 -79.441345
# 15           Downtown     805900  43.666794 -79.388756
# 16    Midtown Toronto         97  43.662872 -79.423233
# 17        Dorset Park     549900  43.749599 -79.270844
# 18           Richview     850000  43.692314 -79.552635
# 19           Downtown    1348000  43.642578 -79.376900
#
#                                  Address      City
# 0                86 Waterford Dr Toronto   Toronto
# 1           #80 - 100 BEDDOE DR Hamilton  Hamilton
# 2             213 Bowman Street Hamilton  Hamilton
# 3               102 NEIL Avenue Hamilton  Hamilton
# 4            #1409 - 230 King St Toronto   Toronto
# 5          254A Monarch Park Ave Toronto   Toronto
# 6               532 Caledonia Rd Toronto   Toronto
# 7             11 REBECCA Street Hamilton  Hamilton
# 8           617 BRIGADOON Drive Hamilton  Hamilton
# 9    51 - 255 MOUNT ALBION Road Hamilton  Hamilton
# 10           1170 LAMBTON Drive Oakville  Oakville
# 11              47 Armstrong Ave Toronto   Toronto
# 12             3 Bracebridge Ave Toronto   Toronto
# 13   #808 - 2167 Lake Shore Blvd Toronto   Toronto
# 14  #2706 - 2167 Lake Shore Blvd Toronto   Toronto
# 15            #710 - 1080 Bay St Toronto   Toronto
# 16              #A - 753 Shaw St Toronto   Toronto
# 17             160 Jenkinson Way Toronto   Toronto
# 18               40 Hawthorne Rd Toronto   Toronto
# 19         #4905 - 16 Harbour St Toronto   Toronto

# %%
# Sort for Toronto only homes
sort_home_sales = home_sales_df.City == "Toronto"
toronto_home_sales = home_sales_df[sort_home_sales]
toronto_home_sales.head()
# Out:
#            AreaName  Price ($)        lat        lng  \
# 0          Richview     999888  43.679882 -79.544266
# 4          Downtown     362000  43.651478 -79.368118
# 5     Old East York    1488000  43.686375 -79.328918
# 6          Fairbank         25  43.691193 -79.461662
# 11  Wallace Emerson        113  43.664101 -79.439751
#
#                           Address     City
# 0         86 Waterford Dr Toronto  Toronto
# 4     #1409 - 230 King St Toronto  Toronto
# 5   254A Monarch Park Ave Toronto  Toronto
# 6        532 Caledonia Rd Toronto  Toronto
# 11       47 Armstrong Ave Toronto  Toronto

# %%
# Clean up Address column by removing "Toronto"
toronto_home_sales["Address"] = toronto_home_sales.Address.str.replace(" Toronto" , "")
toronto_home_sales.head()
# Out:
# C:\Users\haiye\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            AreaName  Price ($)        lat        lng                Address  \
# 0          Richview   999888.0  43.679882 -79.544266        86 Waterford Dr
# 4          Downtown   362000.0  43.651478 -79.368118    #1409 - 230 King St
# 5     Old East York  1488000.0  43.686375 -79.328918  254A Monarch Park Ave
# 6          Fairbank       25.0  43.691193 -79.461662       532 Caledonia Rd
# 11  Wallace Emerson      113.0  43.664101 -79.439751       47 Armstrong Ave
#
#        City
# 0   Toronto
# 4   Toronto
# 5   Toronto
# 6   Toronto
# 11  Toronto

# %%
# Export the Toronto home sales data into a csv
toronto_home_sales.to_csv("output_data/toronto_home_prices.csv")
